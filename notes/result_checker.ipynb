# %%
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.options.display.float_format = '{:.6f}'.format

# %% [markdown]
# ### Study with Sparsity

# %%
with open('./total_result.pickle', mode='rb') as f:
    tot_results = pickle.load(f)
with open('./study.pickle', mode='rb') as f:
    study = pickle.load(f)

# %%
result_df = pd.DataFrame(tot_results)
mean_result_df = result_df.map(lambda x: np.mean(x))
mean_result_df
# Out:
#                  sparseSVDfm  originalfm  NMFdeepfm  originaldeepfm  \
# precision           0.135138    0.449312   0.503823        0.450131
# recall              0.021630    0.080532   0.089874        0.082042
# hit_rate            0.448624    0.862959   0.897936        0.866972
# reciprocal_rank     0.238869    0.678240   0.709410        0.660387
# dcg                 0.399354    1.393211   1.538361        1.377135
# threshold           0.047067         NaN        NaN             NaN
#
#                  sparseNMFdeepfm  SVDdeepfm     NMFfm  sparseSVDdeepfm  \
# precision               0.505152   0.509412  0.247248         0.477793
# recall                  0.091329   0.092294  0.032675         0.088053
# hit_rate                0.905081   0.907917  0.596330         0.894293
# reciprocal_rank         0.709221   0.718435  0.451873         0.686842
# dcg                     1.541335   1.555751  0.806211         1.456589
# threshold               0.030610        NaN       NaN         0.037065
#
#                     SVDfm
# precision        0.170336
# recall           0.024798
# hit_rate         0.512997
# reciprocal_rank  0.309697
# dcg              0.526900
# threshold             NaN

# %%
mean_result_df[['originalfm', 'originaldeepfm', 'SVDfm', 'sparseSVDfm', 'SVDdeepfm', 'sparseSVDdeepfm', 'NMFfm', 'NMFdeepfm', 'sparseNMFdeepfm',]]
# Out:
#                  originalfm  originaldeepfm     SVDfm  sparseSVDfm  SVDdeepfm  \
# precision          0.449312        0.450131  0.170336     0.135138   0.509412
# recall             0.080532        0.082042  0.024798     0.021630   0.092294
# hit_rate           0.862959        0.866972  0.512997     0.448624   0.907917
# reciprocal_rank    0.678240        0.660387  0.309697     0.238869   0.718435
# dcg                1.393211        1.377135  0.526900     0.399354   1.555751
# threshold               NaN             NaN       NaN     0.047067        NaN
#
#                  sparseSVDdeepfm     NMFfm  NMFdeepfm  sparseNMFdeepfm
# precision               0.477793  0.247248   0.503823         0.505152
# recall                  0.088053  0.032675   0.089874         0.091329
# hit_rate                0.894293  0.596330   0.897936         0.905081
# reciprocal_rank         0.686842  0.451873   0.709410         0.709221
# dcg                     1.456589  0.806211   1.538361         1.541335
# threshold               0.037065       NaN        NaN         0.030610

# %% [markdown]
# 1. `sparseSVDfm` $<$ `SVDfm` $<$ `NMFfm` $<$ `originalfm` $<$ `originaldeepfm` $<$ `sparseSVDdeepfm` $<$ `NMFdeepfm` $<$ `sparseNMFdeepfm` $<$ `SVDdeepfm` 순의 성능
# (`precision` 기준)
# 2. [SVD] $<$ [NMF] $<$ [original &\ deepfm] $<$ [SVD & NMF w\ deepfm]

# %% [markdown]
# ### Checking Effects of `num_eigenvector` & `emb_dim`

# %%
with open('./total_result_4.pickle', mode='rb') as f:
    tot_results = pickle.load(f)
result_df = pd.DataFrame(tot_results)

# %%
sorted_num = sorted([int(col[:-5]) for col in result_df.columns])
sorted_col = [str(num) + 'SVDfm' for num in sorted_num]

# %%
result_df = pd.concat([result_df.iloc[:, :7], result_df.iloc[:, 9:]], axis=1)
result_df
# Out:
#                                                             1SVDfm  \
# precision        [0.06926605504587156, 0.14770642201834863, 0.0...
# recall           [0.015405547555220262, 0.0191101569269429, 0.0...
# hit_rate         [0.28440366972477066, 0.4793577981651376, 0.31...
# reciprocal_rank  [0.1418960244648318, 0.26219418960244645, 0.15...
# dcg              [0.2042517318235407, 0.4270980864645613, 0.261...
# exp_var          [0.12184862938387482, 0.12184862938387482, 0.1...
# const_err        [7.306536090915618, 7.306536090915618, 7.30653...
#
#                                                             4SVDfm  \
# precision        [0.05825688073394495, 0.14036697247706423, 0.1...
# recall           [0.008375125842005858, 0.016398610193673734, 0...
# hit_rate         [0.22018348623853212, 0.44724770642201833, 0.5...
# reciprocal_rank  [0.09365443425076452, 0.19105504587155966, 0.2...
# dcg              [0.15526893443694173, 0.3667897326766981, 0.50...
# exp_var          [0.21085839239719578, 0.21085839239719578, 0.2...
# const_err        [6.92634808318144, 6.92634808318144, 6.9263480...
#
#                                                             5SVDfm  \
# precision        [0.08990825688073395, 0.11422018348623852, 0.1...
# recall           [0.011741858864165755, 0.01725312628541994, 0....
# hit_rate         [0.32798165137614677, 0.40825688073394495, 0.3...
# reciprocal_rank  [0.11831039755351681, 0.2342125382262997, 0.19...
# dcg              [0.2231854304903482, 0.35198270382875574, 0.34...
# exp_var          [0.22802749877401207, 0.22802749877401207, 0.2...
# const_err        [6.850586545978746, 6.850586545978746, 6.85058...
#
#                                                             6SVDfm  \
# precision        [0.08486238532110092, 0.014678899082568808, 0....
# recall           [0.008178665904200489, 0.0021007041610662516, ...
# hit_rate         [0.286697247706422, 0.06651376146788991, 0.130...
# reciprocal_rank  [0.1551605504587156, 0.02779051987767584, 0.05...
# dcg              [0.2527120868151884, 0.040156614859138275, 0.0...
# exp_var          [0.24279060760234225, 0.24279060760234225, 0.2...
# const_err        [6.7847654435585705, 6.7847654435585705, 6.784...
#
#                                                             7SVDfm  \
# precision        [0.09311926605504588, 0.06834862385321101, 0.1...
# recall           [0.007575961089095756, 0.006133487772555162, 0...
# hit_rate         [0.286697247706422, 0.23623853211009174, 0.415...
# reciprocal_rank  [0.18000764525993884, 0.1073394495412844, 0.21...
# dcg              [0.29105620397382614, 0.18554154260789718, 0.3...
# exp_var          [0.2542908912200703, 0.2542908912200703, 0.254...
# const_err        [6.733045760054513, 6.733045760054513, 6.73304...
#
#                                                             8SVDfm  \
# precision        [0.16834862385321103, 0.05229357798165138, 0.0...
# recall           [0.02100556321455503, 0.004886342290729274, 0....
# hit_rate         [0.4908256880733945, 0.20642201834862386, 0.26...
# reciprocal_rank  [0.2656345565749235, 0.09430428134556575, 0.11...
# dcg              [0.4864323473964754, 0.14673606641565834, 0.18...
# exp_var          [0.26509518135469307, 0.26509518135469307, 0.2...
# const_err        [6.684091548766204, 6.684091548766204, 6.68409...
#
#                                                             8SVDfm  \
# precision        [0.20412844036697247, 0.12935779816513762, 0.1...
# recall           [0.027413007267691112, 0.01596565007551653, 0....
# hit_rate         [0.5619266055045872, 0.4151376146788991, 0.405...
# reciprocal_rank  [0.4102446483180428, 0.24315749235474005, 0.20...
# dcg              [0.6859654036393669, 0.3973489152793163, 0.348...
# exp_var          [0.26509518135469307, 0.26509518135469307, 0.2...
# const_err        [6.684091548766204, 6.684091548766204, 6.68409...
#
#                                                            11SVDfm  \
# precision        [0.1908256880733945, 0.07568807339449542, 0.20...
# recall           [0.028191326380521447, 0.01242074992722693, 0....
# hit_rate         [0.573394495412844, 0.30963302752293576, 0.584...
# reciprocal_rank  [0.3407874617737003, 0.12817278287461772, 0.36...
# dcg              [0.579158986862606, 0.2032966189190091, 0.6395...
# exp_var          [0.28845147782552705, 0.28845147782552705, 0.2...
# const_err        [6.577019092660965, 6.577019092660965, 6.57701...
#
#                                                            12SVDfm  \
# precision        [0.17155963302752292, 0.12844036697247707, 0.1...
# recall           [0.02389757151297829, 0.019196143952164898, 0....
# hit_rate         [0.5252293577981652, 0.46788990825688076, 0.36...
# reciprocal_rank  [0.34816513761467893, 0.23035168195718655, 0.1...
# dcg              [0.5517701855647672, 0.3703544104348296, 0.268...
# exp_var          [0.2951693293981895, 0.2951693293981895, 0.295...
# const_err        [6.545898081413971, 6.545898081413971, 6.54589...
#
#                                                            14SVDfm  ...  \
# precision        [0.17385321100917434, 0.1743119266055046, 0.13...  ...
# recall           [0.025580154733452473, 0.025396109856001544, 0...  ...
# hit_rate         [0.5344036697247706, 0.5298165137614679, 0.493...  ...
# reciprocal_rank  [0.34009938837920495, 0.32614678899082566, 0.2...  ...
# dcg              [0.5460090060756944, 0.5386920616606169, 0.394...  ...
# exp_var          [0.30734499022367745, 0.30734499022367745, 0.3...  ...
# const_err        [6.489112925374584, 6.489112925374584, 6.48911...  ...
#
#                                                           110SVDfm  \
# precision        [0.1614678899082569, 0.07706422018348624, 0.17...
# recall           [0.02423867603771246, 0.013634774301354171, 0....
# hit_rate         [0.5275229357798165, 0.30963302752293576, 0.53...
# reciprocal_rank  [0.3263379204892967, 0.11242354740061161, 0.31...
# dcg              [0.5064867843671448, 0.19289021761459774, 0.54...
# exp_var          [0.6317642828447833, 0.6317642828447833, 0.631...
# const_err        [4.731401437326837, 4.731401437326837, 4.73140...
#
#                                                           111SVDfm  \
# precision        [0.19862385321100917, 0.11100917431192661, 0.0...
# recall           [0.028116206149298426, 0.016738719673455825, 0...
# hit_rate         [0.5756880733944955, 0.41743119266055045, 0.36...
# reciprocal_rank  [0.40451070336391437, 0.203019877675841, 0.203...
# dcg              [0.656506245088164, 0.3165623476501907, 0.2934...
# exp_var          [0.6340093811429742, 0.6340093811429742, 0.634...
# const_err        [4.716955932177483, 4.716955932177483, 4.71695...
#
#                                                           112SVDfm  \
# precision        [0.19954128440366972, 0.11192660550458715, 0.1...
# recall           [0.02758023465518942, 0.021972593645699652, 0....
# hit_rate         [0.5619266055045872, 0.39908256880733944, 0.41...
# reciprocal_rank  [0.38769113149847095, 0.16918960244648318, 0.2...
# dcg              [0.6519397540501034, 0.29670642701263117, 0.32...
# exp_var          [0.6362875486305322, 0.6362875486305322, 0.636...
# const_err        [4.702252289630728, 4.702252289630728, 4.70225...
#
#                                                           113SVDfm  \
# precision        [0.17018348623853216, 0.18807339449541285, 0.1...
# recall           [0.027344575706441956, 0.026305887474379994, 0...
# hit_rate         [0.5481651376146789, 0.5481651376146789, 0.435...
# reciprocal_rank  [0.330848623853211, 0.3876146788990826, 0.2215...
# dcg              [0.5327823205178724, 0.6302656576038749, 0.353...
# exp_var          [0.6386101436043752, 0.6386101436043752, 0.638...
# const_err        [4.687214422631009, 4.687214422631009, 4.68721...
#
#                                                           114SVDfm  \
# precision        [0.20275229357798166, 0.10275229357798164, 0.1...
# recall           [0.027424524764651525, 0.017793744685554544, 0...
# hit_rate         [0.573394495412844, 0.36009174311926606, 0.552...
# reciprocal_rank  [0.36815749235474005, 0.16731651376146786, 0.3...
# dcg              [0.6354715220911973, 0.2832564530655455, 0.557...
# exp_var          [0.640793613482271, 0.640793613482271, 0.64079...
# const_err        [4.6730332040527625, 4.6730332040527625, 4.673...
#
#                                                           116SVDfm  \
# precision        [0.2018348623853211, 0.1532110091743119, 0.097...
# recall           [0.028789112822340028, 0.023644617256227206, 0...
# hit_rate         [0.5756880733944955, 0.5045871559633027, 0.362...
# reciprocal_rank  [0.40087920489296636, 0.28207186544342505, 0.1...
# dcg              [0.6625809765882659, 0.46534782516549406, 0.27...
# exp_var          [0.6451937836578273, 0.6451937836578273, 0.645...
# const_err        [4.644323385993243, 4.644323385993243, 4.64432...
#
#                                                           117SVDfm  \
# precision        [0.2004587155963303, 0.05229357798165137, 0.15...
# recall           [0.026823962050243965, 0.008885585019637982, 0...
# hit_rate         [0.5458715596330275, 0.22247706422018348, 0.50...
# reciprocal_rank  [0.3663990825688073, 0.1187308868501529, 0.256...
# dcg              [0.6315512568890594, 0.1634420278718576, 0.435...
# exp_var          [0.647384177715847, 0.647384177715847, 0.64738...
# const_err        [4.629965340513413, 4.629965340513413, 4.62996...
#
#                                                           118SVDfm  \
# precision        [0.2, 0.1642201834862385, 0.18073394495412842,...
# recall           [0.026365577288642715, 0.024141434003974217, 0...
# hit_rate         [0.5504587155963303, 0.5068807339449541, 0.566...
# reciprocal_rank  [0.37725535168195723, 0.28700305810397553, 0.3...
# dcg              [0.646644145295281, 0.49523544407410985, 0.550...
# exp_var          [0.6498858233696331, 0.6498858233696331, 0.649...
# const_err        [4.613512379090962, 4.613512379090962, 4.61351...
#
#                                                           127SVDfm  \
# precision        [0.15825688073394495, 0.07477064220183485, 0.1...
# recall           [0.023429859474261572, 0.016278358696086365, 0...
# hit_rate         [0.5252293577981652, 0.29357798165137616, 0.45...
# reciprocal_rank  [0.2959480122324159, 0.15577217125382264, 0.25...
# dcg              [0.4763711519602689, 0.22885350885205313, 0.39...
# exp_var          [0.6687815511843924, 0.6687815511843924, 0.668...
# const_err        [4.487289627738165, 4.487289627738165, 4.48728...
#
#                                                           128SVDfm
# precision        [0.15091743119266057, 0.13073394495412843, 0.2...
# recall           [0.02232162172283063, 0.02187326187355212, 0.0...
# hit_rate         [0.5114678899082569, 0.463302752293578, 0.5756...
# reciprocal_rank  [0.2305428134556575, 0.2186926605504587, 0.401...
# dcg              [0.40727712908130187, 0.36621962297084165, 0.6...
# exp_var          [0.6705853807619614, 0.6705853807619614, 0.670...
# const_err        [4.4750539621579515, 4.4750539621579515, 4.475...
#
# [7 rows x 74 columns]

# %%
# result_df = result_df[sorted_col]
# result_df
mean_result_df = result_df.map(lambda x: np.mean(x))
mean_result_df
# Out:
#                    1SVDfm    4SVDfm    5SVDfm    6SVDfm    7SVDfm    8SVDfm  \
# precision        0.084495  0.102110  0.080826  0.055138  0.094679  0.080183
# recall           0.012421  0.013021  0.009636  0.006303  0.009769  0.008433
# hit_rate         0.307798  0.334862  0.282110  0.206881  0.308716  0.270183
# reciprocal_rank  0.158662  0.164625  0.132653  0.101942  0.189962  0.134671
# dcg              0.245049  0.286713  0.224470  0.160335  0.298800  0.228607
# exp_var          0.121849  0.210858  0.228027  0.242791  0.254291  0.265095
# const_err        7.306536  6.926348  6.850587  6.784765  6.733046  6.684092
#
#                    8SVDfm   11SVDfm   12SVDfm   14SVDfm  ...  110SVDfm  \
# precision        0.150550  0.167156  0.146422  0.156239  ...  0.156697
# recall           0.020680  0.024055  0.021344  0.024757  ...  0.022488
# hit_rate         0.467890  0.511468  0.471560  0.497248  ...  0.483028
# reciprocal_rank  0.276124  0.294121  0.256843  0.302760  ...  0.296193
# dcg              0.461079  0.504094  0.433531  0.487254  ...  0.487328
# exp_var          0.265095  0.288451  0.295169  0.307345  ...  0.631764
# const_err        6.684092  6.577019  6.545898  6.489113  ...  4.731401
#
#                  111SVDfm  112SVDfm  113SVDfm  114SVDfm  116SVDfm  117SVDfm  \
# precision        0.127431  0.142936  0.150917  0.163303  0.138624  0.147982
# recall           0.020528  0.022976  0.024082  0.024815  0.021840  0.022091
# hit_rate         0.442661  0.467890  0.496330  0.510092  0.439908  0.466514
# reciprocal_rank  0.243570  0.244106  0.297714  0.285466  0.272439  0.276835
# dcg              0.385300  0.415374  0.470867  0.486191  0.438733  0.454160
# exp_var          0.634009  0.636288  0.638610  0.640794  0.645194  0.647384
# const_err        4.716956  4.702252  4.687214  4.673033  4.644323  4.629965
#
#                  118SVDfm  127SVDfm  128SVDfm
# precision        0.183119  0.132752  0.133211
# recall           0.026587  0.022374  0.021161
# hit_rate         0.548165  0.440826  0.451835
# reciprocal_rank  0.337431  0.248998  0.242492
# dcg              0.570121  0.403289  0.394637
# exp_var          0.649886  0.668782  0.670585
# const_err        4.613512  4.487290  4.475054
#
# [7 rows x 74 columns]

# %%
performance_metrics = ['precision', 'recall', 'hit_rate', 'reciprocal_rank', 'dcg']
svd_metrics = ['exp_var', 'const_err']

# %%
normalized_df = (mean_result_df - mean_result_df.min(axis=1).values.reshape(-1, 1)) / (mean_result_df.max(axis=1) - mean_result_df.min(axis=1)).values.reshape(-1, 1)

# %%
mean_result_df.T.plot(y='precision')
# Out:
# <Axes: >

# %% [markdown]
# ### DeepFM 확인 - by `num_embeddings`

# %%
with open('./deepfm_result.pickle', mode='rb') as f:
    deep_results = pickle.load(f)
deep_df = pd.DataFrame(deep_results)

# %%
sorted_num = sorted([int(col[:-9]) for col in deep_df.columns])
sorted_col = [str(num) + 'SVDdeepfm' for num in sorted_num]

# %%
mean_deep_df = deep_df[sorted_col].map(lambda x: np.mean(x))
mean_deep_df
# Out:
#                  1SVDdeepfm  2SVDdeepfm  3SVDdeepfm  4SVDdeepfm  5SVDdeepfm  \
# precision          0.356606    0.421009    0.482018    0.500734    0.495780
# recall             0.052055    0.073002    0.086182    0.091179    0.087929
# hit_rate           0.754587    0.824771    0.876606    0.894495    0.891743
# reciprocal_rank    0.567401    0.633035    0.672446    0.689969    0.696743
# dcg                1.114476    1.298793    1.463837    1.516351    1.512351
# exp_var            0.121849    0.159755    0.192403    0.210858    0.228027
# const_err          7.306536    7.147100    7.006873    6.926348    6.850587
#
#                  6SVDdeepfm  7SVDdeepfm  8SVDdeepfm  9SVDdeepfm  10SVDdeepfm  \
# precision          0.514220    0.521560    0.516422    0.517890     0.526881
# recall             0.093599    0.093703    0.092445    0.093176     0.095680
# hit_rate           0.909174    0.910092    0.911009    0.912385     0.915138
# reciprocal_rank    0.713746    0.725168    0.718830    0.717179     0.717959
# dcg                1.563027    1.591615    1.572135    1.573260     1.595761
# exp_var            0.242791    0.254291    0.265095    0.274052     0.281248
# const_err          6.784765    6.733046    6.684092    6.643235     6.610228
#
#                  ...  58SVDdeepfm  61SVDdeepfm  67SVDdeepfm  71SVDdeepfm  \
# precision        ...     0.417798     0.411743     0.409633     0.396972
# recall           ...     0.073625     0.072589     0.071613     0.069649
# hit_rate         ...     0.855046     0.855046     0.843578     0.841284
# reciprocal_rank  ...     0.628081     0.623945     0.607515     0.596743
# dcg              ...     1.273821     1.258584     1.241120     1.202859
# exp_var          ...     0.489058     0.498433     0.517441     0.529830
# const_err        ...     5.573305     5.521936     5.416294     5.346315
#
#                  75SVDdeepfm  76SVDdeepfm  88SVDdeepfm  89SVDdeepfm  \
# precision           0.396239     0.417798     0.404771     0.356881
# recall              0.065945     0.073531     0.070756     0.061398
# hit_rate            0.838532     0.859633     0.838532     0.802752
# reciprocal_rank     0.607087     0.634939     0.607538     0.573135
# dcg                 1.209179     1.277811     1.231077     1.099817
# exp_var             0.541408     0.544223     0.577559     0.579931
# const_err           5.280074     5.263844     5.067691     5.053443
#
#                  94SVDdeepfm  96SVDdeepfm
# precision           0.372661     0.366789
# recall              0.062469     0.061570
# hit_rate            0.804587     0.813303
# reciprocal_rank     0.586131     0.576239
# dcg                 1.146710     1.123787
# exp_var             0.593324     0.598204
# const_err           4.972228     4.942309
#
# [7 rows x 50 columns]

# %%
normalized_df = (mean_deep_df - mean_deep_df.min(axis=1).values.reshape(-1, 1)) / (mean_deep_df.max(axis=1) - mean_deep_df.min(axis=1)).values.reshape(-1, 1)

# %%
# mean_deep_df_T = mean_deep_df.T
mean_deep_df_T = normalized_df.T
mean_deep_df_T.index = mean_deep_df_T.index.map(lambda x: int(x[:-9]))

# %%
plt.figure(figsize=(8, 5))
plt.plot(mean_deep_df_T.index, mean_deep_df_T[svd_metrics + performance_metrics])
plt.xticks(mean_deep_df_T.index, fontsize=7, rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# `SVD + deepFM`의 metrics은 `num_embedding`이 1 - 6일 떄 빠르게 증가했다가 16에서 최대치가 되고 점차 감소함

# %% [markdown]
# ### DeepFM 확인 - by `num_deep_layers`

# %%
with open('./deepfm_result_2.pickle', mode='rb') as f:
    deep_results = pickle.load(f)
deep_df = pd.DataFrame(deep_results)

# %%
sorted_num = sorted([int(col[:-15]) for col in deep_df.columns])
sorted_col = [str(num) + 'layersSVDdeepfm' for num in sorted_num]

# %%
mean_deep_df = deep_df[sorted_col].map(lambda x: np.mean(x))
mean_deep_df
# Out:
#                  1layersSVDdeepfm  2layersSVDdeepfm  3layersSVDdeepfm  \
# precision                0.525138          0.527890          0.506697
# recall                   0.093908          0.096109          0.092597
# hit_rate                 0.909633          0.920183          0.914220
# reciprocal_rank          0.726636          0.733417          0.707630
# dcg                      1.597752          1.607813          1.536727
# exp_var                  0.319258          0.319258          0.319258
# const_err                6.433066          6.433066          6.433066
#
#                  4layersSVDdeepfm  5layersSVDdeepfm  6layersSVDdeepfm  \
# precision                0.518716          0.497431          0.471835
# recall                   0.094322          0.088973          0.084946
# hit_rate                 0.919266          0.901376          0.877064
# reciprocal_rank          0.720979          0.706292          0.670841
# dcg                      1.578820          1.517490          1.434822
# exp_var                  0.319258          0.319258          0.319258
# const_err                6.433066          6.433066          6.433066
#
#                  7layersSVDdeepfm  8layersSVDdeepfm  9layersSVDdeepfm  \
# precision                0.449358          0.349725          0.418532
# recall                   0.078753          0.062497          0.073656
# hit_rate                 0.872477          0.720183          0.842202
# reciprocal_rank          0.646407          0.527974          0.614213
# dcg                      1.362010          1.072014          1.269698
# exp_var                  0.319258          0.319258          0.319258
# const_err                6.433066          6.433066          6.433066
#
#                  10layersSVDdeepfm
# precision                 0.431743
# recall                    0.075449
# hit_rate                  0.847706
# reciprocal_rank           0.618479
# dcg                       1.304924
# exp_var                   0.319258
# const_err                 6.433066

# %%
normalized_df = (mean_deep_df - mean_deep_df.min(axis=1).values.reshape(-1, 1)) / (mean_deep_df.max(axis=1) - mean_deep_df.min(axis=1)).values.reshape(-1, 1)
mean_deep_df_T = normalized_df.T
mean_deep_df_T.index = mean_deep_df_T.index.map(lambda x: int(x[:-15]))

# %%
plt.figure(figsize=(8, 5))
plt.plot(mean_deep_df_T.index, mean_deep_df_T[svd_metrics+performance_metrics])
plt.xticks(mean_deep_df_T.index, fontsize=7, rotation=45)
plt.tight_layout()
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_3975508/443410917.py:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# ### Checking Effects of `SparseSVD`

# %%
with open('../results/temp.pickle', mode='rb') as f:
    df = pickle.load(f)
df = pd.DataFrame(df)

# %%
sorted_num = sorted([int(col[:-11]) for col in df.columns])
sorted_col = [str(num) + 'SparseSVDfm' for num in sorted_num]

# %%
mean_df = df[sorted_col].map(lambda x: np.mean(x))
mean_df
# Out:
#                  1SparseSVDfm  2SparseSVDfm  3SparseSVDfm  4SparseSVDfm  \
# precision            0.227156      0.219908      0.216055      0.223303
# recall               0.027336      0.026230      0.025876      0.026775
# hit_rate             0.561009      0.549541      0.555046      0.562844
# reciprocal_rank      0.393976      0.384702      0.359595      0.354411
# dcg                  0.718868      0.694164      0.665367      0.672967
#
#                  5SparseSVDfm  6SparseSVDfm  7SparseSVDfm  8SparseSVDfm  \
# precision            0.225321      0.232936      0.239083      0.223119
# recall               0.027248      0.028372      0.029238      0.027183
# hit_rate             0.565596      0.575229      0.579817      0.559174
# reciprocal_rank      0.390359      0.405726      0.426353      0.360099
# dcg                  0.707050      0.737918      0.769511      0.679983
#
#                  9SparseSVDfm  10SparseSVDfm  11SparseSVDfm  12SparseSVDfm  \
# precision            0.231468       0.226972       0.232477       0.224037
# recall               0.028873       0.028578       0.028889       0.028306
# hit_rate             0.575688       0.568807       0.569725       0.566055
# reciprocal_rank      0.429434       0.409243       0.416131       0.395971
# dcg                  0.756256       0.729998       0.749847       0.711424
#
#                  13SparseSVDfm  14SparseSVDfm  15SparseSVDfm  16SparseSVDfm  \
# precision             0.221193       0.228440       0.221743       0.222294
# recall                0.028157       0.028813       0.028215       0.027794
# hit_rate              0.576147       0.576147       0.577064       0.568349
# reciprocal_rank       0.389939       0.413509       0.406070       0.403884
# dcg                   0.696009       0.732785       0.713134       0.712383
#
#                  17SparseSVDfm  19SparseSVDfm
# precision             0.224128       0.220000
# recall                0.027691       0.028112
# hit_rate              0.574771       0.579817
# reciprocal_rank       0.398394       0.401292
# dcg                   0.710552       0.701787

# %%
plt.figure(figsize=(8, 5))
plt.plot(mean_df.T.index, mean_df.T['precision'])
plt.xticks(mean_df.T.index, fontsize=7, rotation=45)
plt.tight_layout()
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_979545/203753264.py:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# ### DeepFM + SparseSVD

# %%
with open('../results/sparseSVD_deepfm.pickle', mode='rb') as f:
    ssvd_df = pickle.load(f)
ssvd_df = pd.DataFrame(ssvd_df)

# %%
sorted_num = sorted([int(col[:-15]) for col in ssvd_df.columns])
sorted_col = [str(num) + 'SparseSVDdeepfm' for num in sorted_num]

# %%
mean_ssvd_df = ssvd_df[sorted_col].map(lambda x: np.mean(x))
mean_ssvd_df
# Out:
#                  1SparseSVDdeepfm  3SparseSVDdeepfm  6SparseSVDdeepfm  \
# precision                0.468349          0.469908          0.460550
# recall                   0.079619          0.081733          0.081131
# hit_rate                 0.874312          0.879358          0.874771
# reciprocal_rank          0.677080          0.679534          0.649602
# dcg                      1.434704          1.436436          1.390979
#
#                  7SparseSVDdeepfm  8SparseSVDdeepfm  9SparseSVDdeepfm  \
# precision                0.462477          0.449174          0.451468
# recall                   0.081357          0.079519          0.079132
# hit_rate                 0.874312          0.866972          0.865138
# reciprocal_rank          0.663387          0.648968          0.641483
# dcg                      1.407316          1.365798          1.366014
#
#                  10SparseSVDdeepfm  11SparseSVDdeepfm  12SparseSVDdeepfm  \
# precision                 0.455688           0.450550           0.456606
# recall                    0.080245           0.078897           0.079214
# hit_rate                  0.874771           0.860092           0.861009
# reciprocal_rank           0.652477           0.638823           0.662722
# dcg                       1.382829           1.363549           1.396177
#
#                  13SparseSVDdeepfm  14SparseSVDdeepfm  15SparseSVDdeepfm  \
# precision                 0.459450           0.450367           0.448716
# recall                    0.081899           0.079353           0.079115
# hit_rate                  0.862844           0.870642           0.852294
# reciprocal_rank           0.638815           0.644067           0.629679
# dcg                       1.383838           1.363220           1.352216
#
#                  16SparseSVDdeepfm  17SparseSVDdeepfm  18SparseSVDdeepfm  \
# precision                 0.452752           0.453028           0.445321
# recall                    0.081194           0.078902           0.079091
# hit_rate                  0.860550           0.863761           0.859174
# reciprocal_rank           0.647829           0.653731           0.632469
# dcg                       1.375816           1.378986           1.347521
#
#                  19SparseSVDdeepfm  20SparseSVDdeepfm
# precision                 0.449541           0.454954
# recall                    0.079401           0.080809
# hit_rate                  0.857798           0.862385
# reciprocal_rank           0.636606           0.644885
# dcg                       1.359338           1.377053

# %%
plt.figure(figsize=(8, 5))
plt.plot(mean_ssvd_df.T.index, mean_ssvd_df.T['precision'])
plt.xticks(mean_ssvd_df.T.index, fontsize=7, rotation=45)
plt.tight_layout()
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_979545/3119634659.py:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# ###
